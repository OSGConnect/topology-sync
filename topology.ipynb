# %%
import difflib
from datetime import datetime
from pathlib import Path

from tqdm import tqdm

from client import UserApiClient

c = UserApiClient(token_file_path=Path("token_DO_NOT_VERSION"))

# use c._get("<route>") for low level get request
# use c.get_group("root.osg.VERITAS") to get project

# example where yaml file name doesn't match project name in osgconnect db = duke-campus.yaml -> root.duke.campus
# may need to use display name field from osgconnect to find corresponding yaml file

# %%
c._get("/users/diabate")
# Out:
# {'apiVersion': 'v1alpha1',
#  'kind': 'User',
#  'metadata': {'name': 'Oudou DIABATE',
#   'email': 'diabateoudou@icermali.org',
#   'phone': '+22378587991',
#   'institution': 'ICER - Mali',
#   'public_key': 'ssh-rsa ... diabate@DESKTOP-O4L7IOB',
#   'X.509_DN': '',
#   'unix_name': 'diabate',
#   'unix_id': 13458,
#   'join_date': '2022-Feb-12 22:25:19.537485 UTC',
#   'last_use_time': '2022-Feb-12 22:25:19.537485 UTC',
#   'superuser': False,
#   'service_account': False,
#   'group_memberships': [{'name': 'root.osg.login-nodes.login05',
#     'state': 'active',
#     'state_set_by': 'user:ckoch5'},
#    {'name': 'root.osg.login-nodes',
#     'state': 'active',
#     'state_set_by': 'user:ckoch5'},
#    {'name': 'root.osg.Training-ACE-NIAID',
#     'state': 'active',
#     'state_set_by': 'user:ckoch5'},
#    {'name': 'root.osg', 'state': 'active', 'state_set_by': 'user:ckoch5'},
#    {'name': 'root', 'state': 'active', 'state_set_by': 'user:root'}]}}

# %%
x = set(sorted([u["user_name"] for u in c._get("/groups/root.osg.login-nodes.login05/members")["memberships"]]))

y = sorted(['karres', 'skanyerezi', 'hmutegeki', 'isserwadda', 'rkimera', 'fkakembo', 'diabate', 'artemis', 'shahiid', 'nmike', 'aassoumare', 'rthyagarajan6', 'fatougfofana', 'rnabunje', 'pcbako.traore', 'oumar', 'mohamedmaiga', 'fnsimbi', 'fatoumata', 'dkiberu', 'djjingo', 'pnabisubi', 'mamadou.sangare'])
print(len(y))
for user in y:
    if user in x:
        print(user)
# Out:
# 23
# aassoumare
# artemis
# diabate
# djjingo
# dkiberu
# fatougfofana
# fatoumata
# fkakembo
# fnsimbi
# hmutegeki
# isserwadda
# karres
# mamadou.sangare
# mohamedmaiga
# nmike
# oumar
# pcbako.traore
# pnabisubi
# rkimera
# rnabunje
# shahiid
# skanyerezi

# %%
c._get("/groups/root.osg.MOLLER/members")
# Out:
# {'apiVersion': 'v1alpha1',
#  'memberships': [{'user_name': 'rahmans1',
#    'state': 'active',
#    'state_set_by': 'user:rynge'},
#   {'user_name': 'yug', 'state': 'active', 'state_set_by': 'user:ckoch5'},
#   {'user_name': 'wdconinc', 'state': 'active', 'state_set_by': 'user:root'},
#   {'user_name': 'seehrar', 'state': 'active', 'state_set_by': 'user:rynge'},
#   {'user_name': 'ericking', 'state': 'active', 'state_set_by': 'user:ckoch5'},
#   {'user_name': 'Elhamm', 'state': 'active', 'state_set_by': 'user:rynge'},
#   {'user_name': 'root', 'state': 'admin', 'state_set_by': 'user:root'}]}

# %%
c._get("/groups/root.osg.UC-Staff/attributes/OSG:PI_Organization")
# Out:
# {'apiVersion': 'v1alpha1', 'data': 'University of Chicago'}

# %%
c._get("/groups/root.osg.UC-Staff/attributes/OSG:PI_Name")
# Out:
# {'apiVersion': 'v1alpha1', 'data': 'Rob Gardner'}

# %%
# example group information
c.get_group("root.osg.UC-Staff")
# Out:
# {'apiVersion': 'v1alpha1',
#  'kind': 'Group',
#  'metadata': {'name': 'root.osg.UC-Staff',
#   'display_name': 'UC-Staff',
#   'email': 'paschos@uchicago.edu',
#   'phone': '773-702-4679',
#   'purpose': 'Computer Sciences',
#   'description': 'UC staff group on login04/05 for the purpose of maintenance and perform tests of condor related software after updates and to ensure operational readiness. ',
#   'creation_date': '2022-Jan-04 17:20:21.878544 UTC',
#   'unix_id': 5824,
#   'pending': False}}

# %%
# get all of the "root.osg" projects
# NOTE: display_name is not garuanteed to be the same as project name 
date_fmt = "%Y-%b-%d %H:%M:%S.%f %Z"
osg_projects = list()
for project in tqdm(sorted(list(filter(lambda project: "root.osg" in project, c.get_group_list())))):
    project_data = c.get_group(project)["metadata"]
    osg_projects.append((project, datetime.strptime(project_data["creation_date"], date_fmt)))
# Out:
# 100%|██████████| 639/639 [03:22<00:00,  3.15it/s]

# %%
# check total number of osg projects
osg_projects.sort(key=lambda p: p[1], reverse=True)
print("num osg projects: {}".format(len(osg_projects)))
# Out:
# num osg projects: 636

# %%
print(*osg_projects, sep="\n")
# Out:
# ('root.osg.GATech_Brown', 'vbmSPA', datetime.datetime(2020, 3, 23, 18, 40, 46, 716576))
# ('root.osg.snada', 'social network analysis  ', datetime.datetime(2019, 12, 19, 1, 26, 51, 435423))
# ('root.osg.sPHENIX', 'sPHENIX  ', datetime.datetime(2019, 12, 19, 1, 26, 17, 87695))
# ('root.osg.psims', 'psims  ', datetime.datetime(2019, 12, 19, 1, 25, 52, 75928))
# ('root.osg.BDEML', 'prediction of bond dissocation energy  ', datetime.datetime(2019, 12, 19, 0, 59, 40, 481857))
# ('root.osg.UCF_Wiegand', 'predictTraffic', datetime.datetime(2019, 12, 19, 1, 17, 41, 121026))
# ('root.osg.polymer', 'polymer  ', datetime.datetime(2019, 12, 19, 1, 25, 46, 948783))
# ('root.osg.MCSimulations', 'osg.wsuhep  ', datetime.datetime(2019, 12, 19, 1, 9, 18, 328823))
# ('root.osg', 'osg', datetime.datetime(2019, 12, 19, 0, 58, 48, 329079))
# ('root.osg.nicesims', 'nicesims  ', datetime.datetime(2019, 12, 19, 1, 24, 48, 485457))
# ...

# %%
# get all project files in topology
projects_path = Path("./topology/projects")
project_files = set()
for f in projects_path.iterdir():
    if f.name.endswith(".yaml"):
        project_files.add(f.name.replace(".yaml", ""))
        
class Match:
    global project_files
    
    def __init__(self, project: str, is_perfect_match: bool, date_added: datetime):
        self.project = project
        self.date_added = date_added
        self.is_perfect_match = is_perfect_match
        self.topology_file = project + ".yaml" if is_perfect_match else None
        
        if is_perfect_match:
            self.similar_topology_files = None
        else:
            self.similar_topology_files = difflib.get_close_matches(word=self.project, possibilities=project_files)
    
    def __str__(self):
        base_fmt = "{project:<40}, {match:<2}, {date_added}"
        if self.is_perfect_match:
            return base_fmt.format(project=self.project, match=self.is_perfect_match, date_added=self.date_added)
        else:
            return (base_fmt + ", {similar_files}").format(
                project=self.project,
                match=self.is_perfect_match,
                date_added=self.date_added,
                similar_files=self.similar_topology_files
            )
        
# see what projects match 
matches = list()
for p in osg_projects:
    p_name = p[0].replace("root.osg.", "")
    is_perfect_match = False
    if p_name in project_files:
        is_perfect_match = True

    matches.append(Match(project=p[0], is_perfect_match=is_perfect_match, date_added=p[1]))
    
matches.sort(key=lambda x : x.is_perfect_match)

print(*matches, sep="\n")
        
# get counts
print("*"*80)
print("not matching: ", len(list(filter(lambda x: x.is_perfect_match == False, matches))))
print("matching: ", len(list(filter(lambda x: x.is_perfect_match, matches))))
# Out:
# root.osg                                , 0 , 2019-12-19 00:58:48.329079, []
# root.osg.ASURSCTEST                     , 0 , 2019-12-19 00:58:57.773209, []
# root.osg.Albany_DAES                    , 0 , 2021-09-27 18:51:41.259494, []
# root.osg.Arizona_ResearchTechnologies   , 0 , 2022-01-31 23:02:27.723588, []
# root.osg.Arizona_Sprinkle               , 0 , 2020-11-17 02:27:02.511825, []
# root.osg.Auburn_Carpenter               , 0 , 2019-12-19 00:59:36.520337, []
# root.osg.BDEML                          , 0 , 2019-12-19 00:59:40.481857, []
# root.osg.BGAGenomics                    , 0 , 2019-12-19 00:59:41.699351, ['BGAgenomics', 'Proteomics']
# root.osg.BGUOptics                      , 0 , 2019-12-19 00:59:44.478335, []
# root.osg.BrainLife                      , 0 , 2019-12-19 01:00:39.836746, []
# root.osg.Bucknell_Ryan                  , 0 , 2022-01-11 17:14:22.991305, []
# root.osg.CMU_Viswanathan                , 0 , 2022-02-04 13:11:41.003419, []
# ...

# %% [markdown]
# # template-project.yml
# ```
# # Description is a human-readable description of what the project is about
# # it can be multiple lines as long as each line is indented.
# Description: >-
#   <TEXT>
#
# # Department is the department of the project, e.g. "Physics"
# Department: <DEPT>
# # FieldOfScience is a more specific description, e.g. "High Energy Physics"                                                                                   FieldOfScience: <FOS>                                                                                                                                         # Organization is the organization where the project is hosted, e.g. "University of California, San Diego"
# Organization: <ORG>                                                                                                                                           # PIName is the prinicipal investigator for the project                                                                                                       PIName: <FIRSTNAME> <LASTNAME>
#                                                                                                                                                               Sponsor:                                                                                                                                                        ### If this is an OSG Connect project, uncomment this CampusGrid block
# # CampusGrid:                                                                                                                                                 #   Name: OSG Connect
# ```
#
# - `Department` not needed
# - `Id` not used anymore according to Mats

# %%
# testing GitHub REST API v3
import json
import pprint
from pathlib import Path

import requests

pp = pprint.PrettyPrinter(indent=4)

# get gh access token
with (Path.home() / "ISI/isi-work-notes/gh_token.txt").open("r") as f:
    token = f.read().strip()

r = requests.get('https://api.github.com/users/ryantanaka')

# test repo: https://github.com/ryantanaka/gh-api-test-repo.git

# %%
pp.pprint(json.loads(r.text))
# Out:
# {   'avatar_url': 'https://avatars.githubusercontent.com/u/19616012?v=4',
#     'bio': None,
#     'blog': '',
#     'company': None,
#     'created_at': '2016-05-27T21:52:53Z',
#     'email': None,
#     'events_url': 'https://api.github.com/users/ryantanaka/events{/privacy}',
#     'followers': 5,
#     'followers_url': 'https://api.github.com/users/ryantanaka/followers',
#     'following': 5,
#     'following_url': 'https://api.github.com/users/ryantanaka/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ryantanaka/gists{/gist_id}',
#     'gravatar_id': '',
#     'hireable': None,
#     'html_url': 'https://github.com/ryantanaka',
#     'id': 19616012,
#     'location': 'Los Angeles, California',
#     'login': 'ryantanaka',
#     'name': 'Ryan',
#     'node_id': 'MDQ6VXNlcjE5NjE2MDEy',
#     'organizations_url': 'https://api.github.com/users/ryantanaka/orgs',
#     'public_gists': 4,
#     'public_repos': 26,
# ...

# %%
# GitPython usage
from pathlib import Path
from git import Repo
 
topology = Repo("./topology")
print("before adding test file: {}".format(topology.untracked_files))

# create an empty file in topology
with open("./topology/test-file", mode="w") as f:
    f.write("test")
    
print("after adding test file: {}".format(topology.untracked_files))

Path("./topology/test-file").unlink()

print("after removing test file: {}".format(topology.untracked_files))
# Out:
# before adding test file: []
# after adding test file: ['test-file']
# after removing test file: []

# %%
git = topology.git
git.status()
# Out:
# "On branch master\nYour branch is up to date with 'origin/master'.\n\nnothing to commit, working tree clean"

# %%
help(git.status)
# Out:
# Help on function <lambda> in module git.cmd:
#
# <lambda> lambda *args, **kwargs

# %% [markdown]
# ```
# >>> git.status()
# 'On branch master\nnothing to commit, working tree clean'
# >>> repo.untracked_files
# ['test.txt']
# >>> git.status()
# 'On branch master\nUntracked files:\n  (use "git add <file>..." to include in what will be committed)\n\ttest.txt\n\nnothing added to commit but untracked files present (use "git add" to track)'
# >>> repo.index
# <git.index.base.IndexFile object at 0x108a36770>
# >>> index = repo.index
# >>> for (_path, _stage), entry in index.entries.items():
# ...     pass
# ...
# >>> index.entries.items()
# dict_items([(('README.md', 0), (100644, 493021b1c9e0ecfebcd5ebce646a44138bc60b39, 0, README.md))])
# >>> index.add(["test.txt"])
# [(100644, e69de29bb2d1d6434b8b29ae775ad8c2e48c5391, 0, test.txt)]
# >>> index.entries.items()
# dict_items([(('README.md', 0), (100644, 493021b1c9e0ecfebcd5ebce646a44138bc60b39, 0, README.md)), (('test.txt', 0), (100644, e69de29bb2d1d6434b8b29ae775ad8c2e48c5391, 0, test.txt))])
# >>> index.commit("my commit message")
# <git.Commit "1d33c613bba8ce16265aea6cb932f7f186063717">
# ```

# %%
# get projects added after some date
# check to see if there is a yaml file in topology
# if there is none
#     create the yaml file
#     get information to fill the yaml file <-- query OSGConnect
#     add new file to staging area <-- GitPython
#     commit new file              <-- GitPython
#     use github api to make a pull request to topology <-- Github REST API v3 (requestlib)

# %%
import os
import tempfile

from collections import OrderedDict
from datetime import datetime
from typing import List, Tuple
from pathlib import Path


import yaml
from tqdm import tqdm
from git import Repo 

from client import UserApiClient

client = UserApiClient(token_file_path=Path("token_DO_NOT_VERSION"))

def get_projects_all_projects() -> List[Tuple[str, datetime]]:
    """
    Obtain a list of all projects s.t. project name begins with "root.osg". The output list
    is in the format [("root.osg.example", datetime.datetime(2020, 3, 23, 18, 40, 46, 716576)), ...]
    """
    # get all of the "root.osg" projects
    # NOTE: display_name is not garuanteed to be the same as project name 
    date_fmt = "%Y-%b-%d %H:%M:%S.%f %Z"
    osg_projects = list()
    for project in tqdm(sorted(list(filter(lambda project: "root.osg" in project, client.get_group_list())))):
        project_data = client.get_group(project)["metadata"]
        osg_projects.append((project, datetime.strptime(project_data["creation_date"], date_fmt)))
    
    return osg_projects

def get_all_projects_added_after_date(projects: List[Tuple[str, datetime]], date: datetime) -> List[Tuple[str, datetime]]:
    return list(filter(lambda p: p[1] >= date, projects))

def get_topology_files(topology_projects_dir: Path) -> List[Path]:
    return {f.name.replace(".yaml", "") for f in topology_projects_dir.iterdir() if f.name.endswith(".yaml")}

def create_topology_file(project_name: str, dst: Path) -> None:
    # get information about group
    project_info = client.get_group(project_name)["metadata"]
    
    description = project_info["description"]
    field_of_science = project_info["purpose"]
    organization = client._get("/groups/{}/attributes/OSG:PI_Organization".format(project_name))
    pi_name = client._get("/groups/{}/attributes/OSG:PI_Name".format(project_name)) 
    
    # create entry to be written to topology project file
    entry = OrderedDict(
                [
                    ("Description", description),
                    ("FieldOfScience", field_of_science),
                    ("Organization", organization),
                    ("PIName", pi_name),
                    ("Sponsor", {"CampusGrid": {"Name": "OSG Connect"}})
                ]
            )
    
    # write out new entry 
    with dst.open("w") as f:
        yaml.dump(entry, f)
    
def commit(project: str, topology_repo_path: str) -> None:
    os.chdir(topology_repo_path)
    repo = Repo(".")
    index = repo.index
    origin = repo.remotes.origin # TODO: need to have a check to ensure we have a remote named origin
    
    untracked_files = Set(repo.untracked_files)
    project_file_name = "{}.yaml".format(project)
    if project_file_name in untracked_files:
        index.add(project_file_name)
        index.commit("added topology file for new project: {}".format(project))
        origin.push()
        
        # push to fork
    else:
        # TODO: figure out what to do here, do we want to log an error
        # or do we want to raise an error
        pass
    
    
    # repo.untracked_files -> returns a list of untracked files
    # [item.a_path for item in repo.index.diff(None)] -> returns a list of files that have changed 
    # index.add(["test.txt"]) -> add to git
    # index.commit("commit message") -> commit to git 

def create_pull_request() -> None:
    pass

# %%
import os
import tempfile
from git import Repo

username = "username"
password = "read from token file" # TODO: need to read this from 
remote = "https://{username}:{password}@github.com/topology"

with tempfile.TemporaryDirectory() as tmpdirname:
    Repo.clone_from(remote, tmpdirname)
    repo = Repo(tmpdirname)
